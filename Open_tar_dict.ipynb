# %%
import tarfile
zipfile = 'aclImdb_v1 (1).tar'
if zipfile.endswith("tar.gz"):
    tar = tarfile.open(zipfile, "r:gz")
elif zipfile.endswith("tar"):
    tar = tarfile.open(zipfile, "r:")
tar.extractall()

# %%
import pandas as pd
csv_path = list(n for n in tar.getnames() if n.endswith('.csv'))

# %%
csv_path
# Out:
# []

# %%
tar

# %%
tar.getmembers()
# Out:
# [<TarInfo 'aclImdb' at 0x28776a16040>,
#  <TarInfo 'aclImdb/test' at 0x2877283eb80>,
#  <TarInfo 'aclImdb/train' at 0x2877283e580>,
#  <TarInfo 'aclImdb/test/neg' at 0x2877283e4c0>,
#  <TarInfo 'aclImdb/test/pos' at 0x2877283e940>,
#  <TarInfo 'aclImdb/train/neg' at 0x2877283ec40>,
#  <TarInfo 'aclImdb/train/pos' at 0x2877283ed00>,
#  <TarInfo 'aclImdb/train/unsup' at 0x2877283edc0>,
#  <TarInfo 'aclImdb/imdbEr.txt' at 0x2877283ee80>,
#  <TarInfo 'aclImdb/imdb.vocab' at 0x2877283ea00>,
#  <TarInfo 'aclImdb/README' at 0x2877283eac0>,
#  <TarInfo 'aclImdb/test/labeledBow.feat' at 0x2877283ef40>,
#  <TarInfo 'aclImdb/test/urls_neg.txt' at 0x2877283e880>,
#  <TarInfo 'aclImdb/test/urls_pos.txt' at 0x2877283e7c0>,
#  <TarInfo 'aclImdb/train/unsupBow.feat' at 0x2877283e700>,
#  <TarInfo 'aclImdb/train/labeledBow.feat' at 0x287729fe1c0>,
#  <TarInfo 'aclImdb/train/urls_neg.txt' at 0x287729fe100>,
#  <TarInfo 'aclImdb/train/urls_pos.txt' at 0x28776a16100>,
# ...

# %%
tarfile.open(tar)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2208\4157130376.py in <module>
# ----> 1 tarfile.open(tar)
#
# C:\Anaconda\anaconda\lib\tarfile.py in open(cls, name, mode, fileobj, bufsize, **kwargs)
#    1618                     saved_pos = fileobj.tell()
#    1619                 try:
# -> 1620                     return func(name, "r", fileobj, **kwargs)
#    1621                 except (ReadError, CompressionError):
#    1622                     if fileobj is not None:
#
# C:\Anaconda\anaconda\lib\tarfile.py in gzopen(cls, name, mode, fileobj, compresslevel, **kwargs)
#    1682
#    1683         try:
# -> 1684             fileobj = GzipFile(name, mode + "b", compresslevel, fileobj)
#    1685         except OSError:
#    1686             if fileobj is not None and mode == 'r':
#
# ...

# %%
filename = "aclImdb_v1 (1).tar"

#open file in write mode
file_obj = tarfile.open(filename,"r")

#extract all files
file = file_obj.extractall("extracted_tar_folder")

#close file
file_obj.close()
